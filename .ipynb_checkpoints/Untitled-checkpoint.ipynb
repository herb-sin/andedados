# %%
import requests
from bs4 import BeautifulSoup

url = "https://dados.gov.br/dataset"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.title.text)
# Out:
# Portal de Dados Abertos
